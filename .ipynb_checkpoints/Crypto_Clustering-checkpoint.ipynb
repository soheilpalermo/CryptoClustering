# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e6cf2ee5-398c-459d-a3e9-22652204dff8" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv("Resources/crypto_market_data.csv", index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_market_data)

# %%
# Create a DataFrame with the scaled data

df_scaled = pd.DataFrame(scaled_data, columns=df_market_data.columns, index=df_market_data.index)

# Copy the crypto names from the original DataFrame

crypto_names = df_market_data.index.tolist()

# Set the coin_id column as index

df_scaled.index = crypto_names

# Display the scaled DataFrame

df_scaled.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Data.

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
from sklearn.cluster import KMeans

# Inside the loop:
for k in k_values:
    
# 1. Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k, random_state=0)

# 2. Fit the model to the data using `df_market_data_scaled`
    kmeans.fit(df_scaled)

# 3. Append the model.inertia_ to the inertia list
    inertia.append(kmeans.inertia_)
# Out:
# E:\Soheil\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "E:\Soheil\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "E:\Soheil\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\Soheil\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "E:\Soheil\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {"k": k_values, "inertia": inertia}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow = pd.DataFrame(elbow_data)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
import hvplot.pandas

df_elbow.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve",
    xlabel="Number of Clusters (k)",
    ylabel="Inertia"
)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1176'>
#   <div id="c5bb5f3b-df03-4780-a919-9c94ed18a34e" data-root-id="p1176" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:**
# The best value for k is typically where the "elbow" occurs in the curve. Based on the Elbow Curve, the elbow point  k = 4

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled DataFrame

# %%
# Initialise the K-Means model using the best value for k
kmeans_model = KMeans(n_clusters=4 , random_state=0)

# %%
# Fit the K-Means model using the scaled DataFrame
kmeans_model.fit(df_scaled)
# Out:
# E:\Soheil\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled DataFrame
crypto_clusters = kmeans_model.predict(df_scaled)

# Print the resulting array of cluster values.
print(crypto_clusters)
# Out:
# [2 2 0 0 2 2 2 2 2 0 0 0 0 2 0 2 0 0 2 0 0 2 0 0 0 0 0 0 2 0 0 0 1 2 0 0 3
#  0 0 0 0]

# %%
# Create a copy of the scaled DataFrame
df_scaled_copy = df_scaled.copy()

# %%
# Add a new column to the copy of the scaled DataFrame with the predicted clusters
df_scaled_copy["Cluster"] = crypto_clusters

# Display the copy of the scaled DataFrame
df_scaled_copy.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Colour the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
df_scaled_copy.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="Cluster",
    hover_cols=["coin_id"],  # Replace this with the appropriate column if not available
    title="Cryptocurrency Clusters",
    xlabel="24h Price Change (%)",
    ylabel="7d Price Change (%)",
    width=800,
    height=400
)
# Out:
# :NdOverlay   [Cluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimise Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
from sklearn.decomposition import PCA
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce the original scaled Dataframe
df_market_data_pca = pca.fit_transform(df_scaled)
# View the scaled PCA data
print(pca_data[:5])
# Out:
# [[-0.60066733  0.84276006  0.46159457]
#  [-0.45826071  0.45846566  0.95287678]
#  [-0.43306981 -0.16812638 -0.64175193]
#  [-0.47183495 -0.22266008 -0.47905316]
#  [-1.15779997  2.04120919  1.85971527]]

# %%
# Retrieve the explained variance to determine how much information
explained_variance = pca.explained_variance_ratio_
print("Explained Variance for each component:", explained_variance)

# Calculate the total explained variance
total_explained_variance = explained_variance.sum()
print("Total Explained Variance:", total_explained_variance)
# Out:
# Explained Variance for each component: [0.3719856  0.34700813 0.17603793]
# Total Explained Variance: 0.8950316570309841

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:**

# %%
# Create a new DataFrame with the PCA data.
df_market_data_pca = pd.DataFrame(
    df_market_data_pca,
    columns=["PCA1", "PCA2", "PCA3"]
)

# Copy the crypto names from the original scaled DataFrame
pca_df["coin_id"] = df_scaled_copy.index

# Set the coin_id column as index
pca_df.set_index("coin_id", inplace=True)

# Display the scaled PCA DataFrame
pca_df.head()
# Out:
#                   PCA1      PCA2      PCA3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Scaled PCA DataFrame

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia = []

# Import the KMeans module
from sklearn.cluster import KMeans

# Create a for loop to compute the inertia with each possible value of k
for k in k_values:
    # 1. Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k, random_state=0)
    
    # 2. Fit the model to the data using `df_market_data_pca`
    kmeans.fit(df_market_data_pca)
    
    # 3. Append the model.inertia_ to the inertia list
    inertia.append(kmeans.inertia_)
# Out:
# E:\Soheil\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# E:\Soheil\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# E:\Soheil\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {"k": k_values, "inertia": inertia}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow = pd.DataFrame(elbow_data)

# %%
# Plot a line chart with all the inertia values computed
# with the different values of k to visually identify the optimal value for k
df_elbow.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve",
    xticks=k_values,
    width=800,
    height=400
)
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** k = 4
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No, its Same value

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Scaled PCA DataFrame

# %%
# Initialise the K-Means model using the best value for k
kmeans = KMeans(n_clusters=3, random_state=0)

# %%
# Fit the K-Means model using the scaled PCA DataFrame
kmeans.fit(df_market_data_pca)
# Out:
# E:\Soheil\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled PCA DataFrame
clusters = kmeans.predict(df_market_data_pca)

# Print the resulting array of cluster values.
print("Cluster Values:", clusters)
# Out:
# Cluster Values: [2 2 0 0 2 2 2 2 2 0 0 0 0 2 0 0 0 0 2 0 0 2 0 0 0 0 0 0 2 0 0 0 1 0 0 0 2
#  0 0 0 0]

# %%
# Create a copy of the scaled PCA DataFrame
df_pca_clusters = df_market_data_pca.copy()

# Add a new column to the copy of the PCA DataFrame with the predicted clusters
df_pca_clusters['Cluster'] = clusters

# Display the copy of the scaled PCA DataFrame
print(df_pca_clusters.head())
# Out:
#        PCA1      PCA2      PCA3  Cluster
# 0 -0.600667  0.842760  0.461595        2
# 1 -0.458261  0.458466  0.952877        2
# 2 -0.433070 -0.168126 -0.641752        0
# 3 -0.471835 -0.222660 -0.479053        0
# 4 -1.157800  2.041209  1.859715        2

# %%
# Create a scatter plot using hvPlot by setting
# `x="PC1"` and `y="PC2"`.
# Colour the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
df_pca_clusters['coin_id'] = df_scaled.index  # Add coin_id for hover
scatter_plot = df_pca_clusters.hvplot.scatter(
    x='PCA1',
    y='PCA2',
    c='Cluster',
    hover_cols=['coin_id'],
    title='Cryptocurrency Clusters'
)

scatter_plot
# Out:
# :Scatter   [PCA1]   (PCA2,Cluster,coin_id)

# %% [markdown]
# ### Visualise and Compare the Results
#
# In this section, you will visually analyse the cluster analysis results by contrasting the outcome with and without using the optimisation techniques.

# %%
# Plot for original data
scatter_original = df_scaled_copy.hvplot.scatter(
    x="price_change_percentage_24h", 
    y="price_change_percentage_7d",
    by="Cluster",
    hover_cols=["coin_id"],
    title="Clusters (Original Data)"
)

# Plot for PCA-reduced data
scatter_pca = df_pca_clusters.hvplot.scatter(
    x="PCA1", 
    y="PCA2",
    by="Cluster",
    hover_cols=["coin_id"],
    title="Clusters (PCA Reduced Data)"
)

# Overlay the plots
scatter_original + scatter_pca
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [Cluster]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d)
#    .NdOverlay.II :NdOverlay   [Cluster]
#       :Scatter   [PCA1]   (PCA2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analysing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:**
#
# **Reduced Dimensionality:**
#
# * By reducing the number of features with PCA, the computational complexity of the K-Means algorithm is significantly reduced. This makes clustering faster and more efficient, especially for large datasets.
#
# **Preserved Patterns:**
# * The clustering patterns in the PCA-reduced data generally align with those in the original data. This demonstrates that PCA effectively captures the key variance in the data, preserving essential clustering structures while discarding less significant noise or redundant information.
#
# **Simpler Visualizations:**
# * Clustering results are easier to interpret in two or three dimensions (as provided by PCA components). This is particularly helpful when visualizing clusters in scatter plots.
#
# **Potential Loss of Detail:**
#
# * While PCA reduces dimensions, there may be a slight loss of granularity or subtle nuances in the data that could affect clustering in cases where the discarded dimensions hold minor, but relevant, clustering information.
#
# **Consistency in k:**
# * The optimal k value observed in the PCA-reduced data often remains consistent with the original data, ensuring reliable clustering results.
#
# ##### In summary, using fewer features via PCA simplifies and accelerates the clustering process without significantly compromising the quality of the clusters. However, it's essential to verify that the retained components account for a sufficient proportion of the variance to ensure meaningful results.
